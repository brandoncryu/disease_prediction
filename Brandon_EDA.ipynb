# %%
import pandas as pd

# %% [markdown]
# ## EDA questions:
#
# * What are the most common diagnoses
#     * Which disease do we want to investigate?
# * What are the most common lab tests run for patients with/ wo CHF
#     * Which labs should we use as features?
# * What diagnoses are associated wtih CHF (co-morbidity)?
#     * Can we use certain diagnosis as features? (coronary artery disease, high blood pressure, diabetes or obesity)
# * How many times did patients visit the hospital before their first CHF diagnosis?
#     * Justify the need for model

# %%
diag = pd.read_csv('./data/hosp/diagnoses_icd.csv.gz', compression='gzip')
diag_d = pd.read_csv('./data/hosp/d_icd_diagnoses.csv.gz', compression='gzip')

# %%
# Merge diagnosis data with icd definition
diag = diag.merge(diag_d, how='left', on='icd_code')
diag.long_title.value_counts().head(20)
# Out:
# Unspecified essential hypertension                                                                            81275
# Other and unspecified hyperlipidemia                                                                          57076
# Essential (primary) hypertension                                                                              53652
# Hyperlipidemia, unspecified                                                                                   50353
# Acute kidney failure, unspecified                                                                             44091
# Personal history of nicotine dependence                                                                       40097
# Esophageal reflux                                                                                             40062
# Gastro-esophageal reflux disease without esophagitis                                                          35044
# Diabetes mellitus without mention of complication, type II or unspecified type, not stated as uncontrolled    34103
# Anemia, unspecified                                                                                           33740
# Depressive disorder, not elsewhere classified                                                                 31032
# Major depressive disorder, single episode, unspecified                                                        30101
# Atrial fibrillation                                                                                           29418
# Personal history of tobacco use                                                                               29333
# Congestive heart failure, unspecified                                                                         28539
# Coronary atherosclerosis of native coronary artery                                                            28125
# Urinary tract infection, site not specified                                                                   27186
# Encounter for immunization                                                                                    27021
# Obesity, unspecified                                                                                          26594
# Atherosclerotic heart disease of native coronary artery without angina pectoris                               26533
# Name: long_title, dtype: int64

# %%
# diag[diag.long_title.str.lower().str.contains('congestive') & diag.long_title.str.lower().str.contains('heart') & diag.long_title.str.lower().str.contains('failure')].icd_code.unique()
diag[diag.long_title.str.lower().str.contains('celiac disease').fillna(False)].long_title.unique()
# Out:
# array(['Celiac disease'], dtype=object)

# %%
# Create target table that show whether a patient has had CHF diagnosis or not
# diag['has_CHF']=diag.long_title.str.lower().str.contains('congestive') & diag.long_title.str.lower().str.contains('heart') & diag.long_title.str.lower().str.contains('failure')
# diag.has_CHF.replace({False:0, True:1}, inplace=True)
# subj_hasCHF = diag.groupby('subject_id').sum()['has_CHF'].agg(lambda x: 1 if x>0 else 0).reset_index()


# Create target table that show whether a patient has had celiac disease or not
diag['has_celiac']=diag.long_title.str.lower().str.contains('celiac disease')
diag.has_celiac.replace({False:0, True:1}, inplace=True)
subj_hasCeliac = diag.groupby('subject_id').sum()['has_celiac'].agg(lambda x: 1 if x>0 else 0).reset_index()
adm_hasCeliac = diag.groupby('hadm_id').sum()['has_celiac'].agg(lambda x: 1 if x>0 else 0).reset_index()

# %%
subj_hasCeliac.mean()
adm_hasCeliac.mean()
# diag.has_celiac.mean()
# Out:
# hadm_id       2.500397e+07
# has_celiac    2.913781e-03
# dtype: float64

# %% [markdown]
# Celiac Disease: 0.3% of admissions

# %% [markdown]
# ### ICU
# * how many patients with CHF were in the ICU?
# * how many patients were in the ICU vs not
# * how many visits were in the ICU vs not
# * what are the ICU events that are most commonly done?
# * How many times is BP (and other vitals/labs) taken for each ICU stay/patient?
# * Are these patients found in the diagnosis table?
# * What are most common labs for ICU patients?

# %%
# import chartevents

chunksize = 3*(10 ** 6)
counter=0
chart_events = []
for chunk in pd.read_csv('./data/icu/chartevents.csv.gz', compression='gzip', chunksize=chunksize):
    chart_events.append(chunk)
    counter+=1
    print(f'chunk {counter} processed')
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs
# /Users/brandonryu/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk 1 processed
# chunk 2 processed
# chunk 3 processed
# chunk 4 processed
# /Users/brandonryu/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk 5 processed
# chunk 6 processed
# chunk 7 processed
# chunk 8 processed
# chunk 9 processed
# chunk 10 processed
# chunk 11 processed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-575b3984d799> in <module>
#       6 get_ipython().run_line_magic('time', '')
#       7 while counter <10:
# ----> 8     for chunk in pd.read_csv('./data/icu/chartevents.csv.gz', compression='gzip', chunksize=chunksize):
#       9         chart_events.append(chunk)
#      10         counter+=1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1105     def __next__(self):
#    1106         try:
# -> 1107             return self.get_chunk()
#    1108         except StopIteration:
#    1109             self.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1165                 raise StopIteration
#    1166             size = min(size, self.nrows - self._currow)
# -> 1167         return self.read(nrows=size)
#    1168
#    1169
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ~/opt/anaconda3/lib/python3.7/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~/opt/anaconda3/lib/python3.7/gzip.py in read(self, size)
#     469             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     470
# --> 471             uncompress = self._decompressor.decompress(buf, size)
#     472             if self._decompressor.unconsumed_tail != b"":
#     473                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
chart_event_final = pd.concat(chart_events)
# chart_events[0]

# %%
d_items = pd.read_csv('./data/icu/d_items.csv.gz', compression='gzip')

# %%
d_routine_vitals = d_items[(d_items.linksto =='chartevents')& (d_items.category=='Routine Vital Signs')]
# d_items[(d_items['label'].str.contains('Heart'))]

# %%
# d_routine_vitals
# d_items

# %%
# chart1_vitals = chart_events[0].merge(d_routine_vitals, how='right', on='itemid')
# chart1_vitals[-chart1_vitals.valuenum.isna()]

# %%
# most commonly done chart events
common_events_icu = chart_events[0].groupby(['subject_id','itemid']).count().reset_index().itemid.value_counts().head(100).to_frame().reset_index().merge(d_items, left_on='index', right_on='itemid', how='left')

# %%
common_items = common_events_icu[common_events_icu.category != 'Alarms'].head(50).itemid_y.tolist()

# %%
chart_1 = chart_events[0]

# %% [markdown]
# ### Median number of times each common event occured per patient visit

# %%
test = chart_1[chart_1.itemid.isin(common_items)].merge(d_items, how='left', on='itemid')
test.groupby(['hadm_id','itemid']).count().reset_index().groupby('itemid').median()[['subject_id']].reset_index().merge(d_items, on='itemid', how='left')
# Out:
#     itemid  subject_id                                        label  \
# 0   220045        51.0                                   Heart Rate
# 1   220179        35.0         Non Invasive Blood Pressure systolic
# 2   220180        35.0        Non Invasive Blood Pressure diastolic
# 3   220181        36.0             Non Invasive Blood Pressure mean
# 4   220210        50.0                             Respiratory Rate
# 5   220228         4.0                                   Hemoglobin
# 6   220277        50.0                  O2 saturation pulseoxymetry
# 7   220545         4.0                           Hematocrit (serum)
# 8   220546         3.0                                          WBC
# 9   220602         3.0                             Chloride (serum)
# 10  220615         3.0                           Creatinine (serum)
# 11  220621         3.0                              Glucose (serum)
# 12  220635         3.0                                    Magnesium
# 13  220645         3.0                               Sodium (serum)
# 14  223761        12.0                       Temperature Fahrenheit
# 15  223834         7.0                                      O2 Flow
# 16  223835         9.0                         Inspired O2 Fraction
# 17  224639         2.0                                 Daily Weight
# 18  225087         2.0                     Visual / hearing deficit
# 19  225092         2.0                                     Self ADL
# 20  225094         2.0                     History of slips / falls
# 21  225103         2.0  Intravenous  / IV access prior to admission
# 22  225106         2.0                                         ETOH
# 23  225113         2.0                  Currently experiencing pain
# 24  225118         2.0                        Difficulty swallowing
# 25  225126         2.0                             Dialysis patient
# 26  225184         2.0                                     Eye Care
# 27  225624         3.0                                          BUN
# 28  225625         3.0                          Calcium non-ionized
# 29  225664         8.0          Glucose finger stick (range 70-100)
# 30  225668         2.0                                  Lactic Acid
# 31  225677         3.0                                  Phosphorous
# 32  226137         7.0          18 Gauge placed in outside facility
# 33  226138         8.0          20 Gauge placed in outside facility
# 34  226531         2.0                      Admission Weight (lbs.)
# 35  227073         3.0                                    Anion gap
# 36  227349         3.0                High risk (>51) interventions
# 37  227367         7.0                  18 Gauge Dressing Occlusive
# 38  227368         8.0                  20 Gauge Dressing Occlusive
# 39  227442         4.0                            Potassium (serum)
# 40  227443         3.0                                 HCO3 (serum)
# 41  227457         3.0                               Platelet Count
# 42  227465         2.0                             Prothrombin time
# 43  227466         2.0                                          PTT
# 44  227467         2.0                                          INR
# 45  228099         7.0                 18 Gauge placed in the field
# 46  228100         8.0                 20 Gauge placed in the field
# 47  228236         2.0                                 Insulin pump
# 48  228648         2.0                                      Home TF
# 49  228649         2.0                       Pressure Ulcer Present
#
#                                    abbreviation      linksto  \
# 0                                            HR  chartevents
# 1                                          NBPs  chartevents
# 2                                          NBPd  chartevents
# 3                                          NBPm  chartevents
# 4                                            RR  chartevents
# 5                                    Hemoglobin  chartevents
# 6                                          SpO2  chartevents
# 7                            Hematocrit (serum)  chartevents
# 8                                           WBC  chartevents
# 9                              Chloride (serum)  chartevents
# 10                           Creatinine (serum)  chartevents
# 11                              Glucose (serum)  chartevents
# 12                                    Magnesium  chartevents
# 13                               Sodium (serum)  chartevents
# 14                                Temperature F  chartevents
# 15                                      O2 Flow  chartevents
# 16                                         FiO2  chartevents
# 17                                 Daily Weight  chartevents
# 18                     Visual / hearing deficit  chartevents
# 19                                     Self ADL  chartevents
# 20                     History of slips / falls  chartevents
# 21  Intravenous  / IV access prior to admission  chartevents
# 22                                         ETOH  chartevents
# 23                  Currently experiencing pain  chartevents
# 24                        Difficulty swallowing  chartevents
# 25                             Dialysis patient  chartevents
# 26                                     Eye Care  chartevents
# 27                                          BUN  chartevents
# 28                          Calcium non-ionized  chartevents
# 29                   Glucose FS (range 70 -100)  chartevents
# 30                                  Lactic Acid  chartevents
# 31                                  Phosphorous  chartevents
# 32          18 Gauge placed in outside facility  chartevents
# 33          20 Gauge placed in outside facility  chartevents
# 34                      Admission Weight (lbs.)  chartevents
# 35                                    Anion gap  chartevents
# 36                High risk (>51) interventions  chartevents
# 37                  18 Gauge Dressing Occlusive  chartevents
# 38                  20 Gauge Dressing Occlusive  chartevents
# 39                            Potassium (serum)  chartevents
# 40                                 HCO3 (serum)  chartevents
# 41                               Platelet Count  chartevents
# 42                                           PT  chartevents
# 43                                          PTT  chartevents
# 44                                          INR  chartevents
# 45                 18 Gauge placed in the field  chartevents
# 46                 20 Gauge placed in the field  chartevents
# 47                                 Insulin pump  chartevents
# 48                                      Home TF  chartevents
# 49                       Pressure Ulcer Present  chartevents
#
#                      category  unitname        param_type  lownormalvalue  \
# 0         Routine Vital Signs       bpm           Numeric             NaN
# 1         Routine Vital Signs      mmHg           Numeric             NaN
# 2         Routine Vital Signs      mmHg           Numeric             NaN
# 3         Routine Vital Signs      mmHg           Numeric             NaN
# 4                 Respiratory  insp/min           Numeric             NaN
# 5                        Labs      g/dl           Numeric             NaN
# 6                 Respiratory         %           Numeric             NaN
# 7                        Labs      None           Numeric             NaN
# 8                        Labs      None           Numeric             NaN
# 9                        Labs      None           Numeric             NaN
# 10                       Labs      None           Numeric             NaN
# 11                       Labs      None           Numeric             NaN
# 12                       Labs      None           Numeric             NaN
# 13                       Labs      None           Numeric             NaN
# 14        Routine Vital Signs        °F           Numeric             NaN
# 15                Respiratory     L/min           Numeric             NaN
# 16                Respiratory      None           Numeric             NaN
# 17                    General        kg           Numeric             NaN
# 18           Adm History/FHPA       NaN          Checkbox             NaN
# 19           Adm History/FHPA       NaN          Checkbox             NaN
# 20           Adm History/FHPA       NaN          Checkbox             NaN
# 21           Adm History/FHPA       NaN          Checkbox             NaN
# 22           Adm History/FHPA       NaN          Checkbox             NaN
# 23           Adm History/FHPA       NaN          Checkbox             NaN
# 24           Adm History/FHPA       NaN          Checkbox             NaN
# 25           Adm History/FHPA       NaN          Checkbox             NaN
# 26                 Treatments       NaN          Checkbox             NaN
# 27                       Labs      None           Numeric             NaN
# 28                       Labs      None           Numeric             NaN
# 29                       Labs      None           Numeric             NaN
# 30                       Labs      None           Numeric             NaN
# 31                       Labs      None           Numeric             NaN
# 32  Access Lines - Peripheral       NaN          Checkbox             NaN
# 33  Access Lines - Peripheral       NaN          Checkbox             NaN
# 34                    General      None           Numeric             NaN
# 35                       Labs      None           Numeric             NaN
# 36  Restraint/Support Systems       NaN          Checkbox             NaN
# 37  Access Lines - Peripheral       NaN          Checkbox             NaN
# 38  Access Lines - Peripheral       NaN          Checkbox             NaN
# 39                       Labs      None  Numeric with tag             NaN
# 40                       Labs      None  Numeric with tag             NaN
# 41                       Labs      None  Numeric with tag             NaN
# 42                       Labs      None  Numeric with tag             NaN
# 43                       Labs      None  Numeric with tag             NaN
# 44                       Labs      None  Numeric with tag             NaN
# 45  Access Lines - Peripheral       NaN          Checkbox             NaN
# 46  Access Lines - Peripheral       NaN          Checkbox             NaN
# 47           Adm History/FHPA       NaN          Checkbox             NaN
# 48           Adm History/FHPA       NaN          Checkbox             NaN
# 49           Adm History/FHPA       NaN          Checkbox             NaN
#
#     highnormalvalue
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              NaN

# %% [markdown]
# ### Are patients in ICU found in diagnosis

# %%
test_admits = chart_1.groupby('hadm_id').count().reset_index()[['hadm_id']]
test_admits.merge(diag, how='left', on='hadm_id')
# test_admits

# yes all patients in ICU can be found in diagnosis_ICD table. Keep in mind, multiple diagnosis per visit.
# Patients can have visits outside ICU.
# Out:
#         hadm_id  subject_id  seq_num icd_code  icd_version_x  icd_version_y  \
# 0      20005763  10628534.0      4.0  E7800             10.0           10.0
# 1      20005763  10628534.0      9.0  R008              10.0           10.0
# 2      20005763  10628534.0      6.0  I2510             10.0           10.0
# 3      20005763  10628534.0      3.0  I10               10.0           10.0
# 4      20005763  10628534.0      1.0  I7102             10.0           10.0
# ...         ...         ...      ...      ...            ...            ...
# 32075  29994501  11031780.0     12.0  53081              9.0            9.0
# 32076  29994501  11031780.0      7.0  2724               9.0            9.0
# 32077  29994501  11031780.0     11.0  496                9.0            9.0
# 32078  29994501  11031780.0      9.0  51889              9.0            9.0
# 32079  29994501  11031780.0      5.0  4019               9.0            9.0
#
#                                               long_title
# 0                 Pure hypercholesterolemia, unspecified
# 1                      Other abnormalities of heart beat
# 2      Atherosclerotic heart disease of native corona...
# 3                       Essential (primary) hypertension
# 4                          Dissection of abdominal aorta
# ...                                                  ...
# 32075                                  Esophageal reflux
# 32076               Other and unspecified hyperlipidemia
# 32077  Chronic airway obstruction, not elsewhere clas...
# 32078   Other diseases of lung, not elsewhere classified
# 32079                 Unspecified essential hypertension
#
# [32080 rows x 7 columns]

# %%
d_items[d_items.itemid==220045]
# Out:
#    itemid       label abbreviation      linksto             category unitname  \
# 1  220045  Heart Rate           HR  chartevents  Routine Vital Signs      bpm
#
#   param_type  lownormalvalue  highnormalvalue
# 1    Numeric             NaN              NaN

# %%
# chart_events[0].groupby(['subject_id','itemid']).count().reset_index().subject_id.nunique()
chart_merged = chart_events[0].merge(d_items, how='left', on='itemid')

# chart_merged.groupby(['subject_id','itemid']).count().reset_index()

# %%
chart_merged[chart_merged.itemid==220277]
# Out:
#          subject_id   hadm_id   stay_id            charttime  \
# 67         10003700  28623837  35053963  2165-04-24 05:31:00
# 92         10003700  28623837  35053963  2165-04-24 06:00:00
# 120        10003700  28623837  35053963  2165-04-24 06:09:00
# 127        10003700  28623837  35053963  2165-04-24 07:00:00
# 177        10003700  28623837  35053963  2165-04-24 08:00:00
# ...             ...       ...       ...                  ...
# 2999900    12426769  26860378  30486026  2164-04-27 20:00:00
# 2999943    12426769  26860378  30486026  2164-04-27 21:00:00
# 2999970    12426769  26860378  30486026  2164-04-27 22:00:00
# 2999981    12426769  26860378  30486026  2164-04-27 23:00:00
# 2999986    12426769  26860378  30486026  2164-04-28 00:00:00
#
#                    storetime  itemid value  valuenum valueuom  warning  \
# 67       2165-04-24 05:37:00  220277   100     100.0        %        0
# 92       2165-04-24 05:42:00  220277   100     100.0        %        0
# 120      2165-04-24 06:09:00  220277   100     100.0        %        0
# 127      2165-04-24 07:37:00  220277   100     100.0        %        0
# 177      2165-04-24 08:19:00  220277   100     100.0        %        0
# ...                      ...     ...   ...       ...      ...      ...
# 2999900  2164-04-27 20:51:00  220277    98      98.0        %        0
# 2999943  2164-04-27 23:46:00  220277   100     100.0        %        0
# 2999970  2164-04-27 23:46:00  220277    99      99.0        %        0
# 2999981  2164-04-27 23:46:00  220277   100     100.0        %        0
# 2999986  2164-04-28 00:22:00  220277    97      97.0        %        0
#
#                                label abbreviation      linksto     category  \
# 67       O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 92       O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 120      O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 127      O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 177      O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# ...                              ...          ...          ...          ...
# 2999900  O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 2999943  O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 2999970  O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 2999981  O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
# 2999986  O2 saturation pulseoxymetry         SpO2  chartevents  Respiratory
#
#         unitname param_type  lownormalvalue  highnormalvalue
# 67             %    Numeric             NaN              NaN
# 92             %    Numeric             NaN              NaN
# 120            %    Numeric             NaN              NaN
# 127            %    Numeric             NaN              NaN
# 177            %    Numeric             NaN              NaN
# ...          ...        ...             ...              ...
# 2999900        %    Numeric             NaN              NaN
# 2999943        %    Numeric             NaN              NaN
# 2999970        %    Numeric             NaN              NaN
# 2999981        %    Numeric             NaN              NaN
# 2999986        %    Numeric             NaN              NaN
#
# [201015 rows x 18 columns]

# %%
d_hcpc = pd.read_csv('./data/mimic-iv-0.4/hosp/d_hcpcs.csv.gz', compression='gzip')

# %%
d_hcpc[d_hcpc.long_description.fillna('0').str.lower().str.contains('history')]
# Out:
#        code  category                                   long_description  \
# 97    G9          NaN  Monitored anesthesia care for patient who has ...
# 2100  G0245       NaN  Initial physician evaluation and management of...
# 2101  G0246       NaN  Follow-up physician evaluation and management ...
# 2267  G0505       NaN  Cognition and functional assessment using stan...
# 2426  G8560       NaN  Patient has a history of active drainage from ...
# 2427  G8561       NaN  Patient is not eligible for the referral for o...
# 2428  G8562       NaN  Patient does not have a history of active drai...
# 2619  G8861       NaN  Within the past 2 years, central dual-energy x...
# 2979  G9277       NaN  Documentation that the patient is on daily asp...
# 2984  G9282       NaN  Documentation of medical reason(s) for not rep...
# 2990  G9288       NaN  Documentation of medical reason(s) for not rep...
# 2995  G9292       NaN  Documentation of medical reason(s) for not rep...
# 3001  G9298       NaN  Patients who are evaluated for venous thromboe...
# 3002  G9299       NaN  Patients who are not evaluated for venous thro...
# 3105  G9419       NaN  Documentation of medical reason(s) for not inc...
# 3116  G9429       NaN  Documentation of medical reason(s) for not inc...
# 3123  G9436       NaN  Aspirin not prescribed for documented reasons ...
# 3126  G9439       NaN  P2y inhibitor not prescribed for documented re...
# 3132  G9449       NaN  History of receiving blood transfusions prior ...
# 3133  G9450       NaN                      History of injection drug use
# 3153  G9472       NaN  Within the past 2 years, central dual-energy x...
# 3162  G9481       NaN  Remote in-home visit for the evaluation and ma...
# 3163  G9482       NaN  Remote in-home visit for the evaluation and ma...
# 3164  G9483       NaN  Remote in-home visit for the evaluation and ma...
# 3165  G9484       NaN  Remote in-home visit for the evaluation and ma...
# 3166  G9485       NaN  Remote in-home visit for the evaluation and ma...
# 3167  G9486       NaN  Remote in-home visit for the evaluation and ma...
# 3168  G9487       NaN  Remote in-home visit for the evaluation and ma...
# 3172  G9488       NaN  Remote in-home visit for the evaluation and ma...
# 3173  G9489       NaN  Remote in-home visit for the evaluation and ma...
# 3315  G9659       NaN  Patients greater than 85 years of age who did ...
# 3316  G9660       NaN  Documentation of medical reason(s) for a colon...
# 3364  G9708       NaN  Women who had a bilateral mastectomy or who ha...
# 3367  G9711       NaN  Patients with a diagnosis or past history of t...
# 3372  G9759       NaN  History of preoperative posterior capsule rupture
# 3384  G9722       NaN  Documented history of renal failure or baselin...
# 3437  G9782       NaN  History of or active diagnosis of familial or ...
# 3449  G9794       NaN  Documentation of medical reason(s) for not on ...
# 3454  G9799       NaN  Patients with a medication dispensing event in...
# 3517  G9862       NaN  Documentation of medical reason(s) for not rec...
# 3580  G9936       NaN  Surveillance colonoscopy - personal history of...
# 3613  G9978       NaN  Remote in-home visit for the evaluation and ma...
# 3615  G9979       NaN  Remote in-home visit for the evaluation and ma...
# 3616  G9980       NaN  Remote in-home visit for the evaluation and ma...
# 3617  G9981       NaN  Remote in-home visit for the evaluation and ma...
# 3618  G9982       NaN  Remote in-home visit for the evaluation and ma...
# 3619  G9983       NaN  Remote in-home visit for the evaluation and ma...
# 3620  G9984       NaN  Remote in-home visit for the evaluation and ma...
# 3621  G9985       NaN  Remote in-home visit for the evaluation and ma...
# 3622  G9986       NaN  Remote in-home visit for the evaluation and ma...
# 5569  M1018       NaN  Patients with an active diagnosis or history o...
# 5607  M1056       NaN  Prescribed anticoagulant medication during the...
# 6065  S0260       NaN  History and physical (outpatient or office) re...
#
#                  short_description
# 97         Mac for at risk patient
# 2100     Initial foot exam pt lops
# 2101  Followup eval of foot pt lop
# 2267      Cog/func assessmentoutpt
# 2426  Pt hx act drain prev 90 days
# 2427    Pt inelig for ref oto eval
# 2428       Pt no hx act drain 90 d
# 2619         Dxa ordered for osteo
# 2979   Doc daily aspirin or contra
# 2984      Doc medrsn no histo type
# 2990   Doc medrsn no hist type rpt
# 2995         Medrsn no pt category
# 3001  Eval risk vte card 30d prior
# 3002  No eval riskk vte card prior
# 3105  Med reas not incl histo type
# 3116         Doc med rsn no pt cat
# 3123        Asp not presc doc reas
# 3126  P2y inhib not presc doc reas
# 3132        Hx bld transf b/f 1992
# 3133             Hx injec drug use
# 3153     No dxa no med hx no rv sx
# 3162      Remote e/m new pt 10mins
# 3163      Remote e/m new pt 20mins
# 3164      Remote e/m new pt 30mins
# 3165      Remote e/m new pt 45mins
# 3166      Remote e/m new pt 60mins
# 3167     Remote e/m est. pt 10mins
# 3168     Remote e/m est. pt 15mins
# 3172     Remote e/m est. pt 25mins
# 3173     Remote e/m est. pt 40mins
# 3315  >85y no hx colo ca/rsn scope
# 3316     Doc med rsn scope pt >85y
# 3364  Bilat mast/hx bi /unilat mas
# 3367     Pt hx tot col or colon ca
# 3372         Hx preop post cap rup
# 3384   Doc hx renal fail or cr+ >4
# 3437    Hx dx fam/pure hypercholes
# 3449  Doc med rsn no daily aspirin
# 3454    Med disp evt indic hx asth
# 3517       Doc rsn no 10 yr follow
# 3580  Pmh plyp/neo co/rect/jun/ans
# 3613      Remote e/m new pt 10mins
# 3615      Remote e/m new pt 20mins
# 3616     Remote e/m new pt 30 mins
# 3617      Remote e/m new pt 45mins
# 3618      Remote e/m new pt 60mins
# 3619     Remote e/m est. pt 10mins
# 3620      Remote e/m est. pt15mins
# 3621     Remote e/m est. pt 25mins
# 3622     Remote e/m est. pt 40mins
# 5569  Pt dx hst cr pt sk lg cr scr
# 5607        Presc antico med in pp
# 6065               H&p for surgery

# %% [markdown]
# ## Processing for model

# %%
diag[diag.long_title.str.lower().str.contains('celiac disease').fillna(False)].long_title.unique()
# Out:
# array(['Celiac disease'], dtype=object)

# %%
# df.loc[df.reset_index().groupby(['F_Type'])['to_date'].idxmax()]
