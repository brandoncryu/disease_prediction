# %% [markdown]
# ## Base Models

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_roc_curve
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %%
pos_final_test = pd.read_csv('./data/pos_final_test.csv.gz', compression='gzip')
pos_final_test_KNN = pd.read_csv('./data/pos_KNN_final_test.csv.gz', compression='gzip')
pos_final_missing_data_test = pd.read_csv('./data/./pos_final_missing_data_test.csv.gz', compression='gzip')

# %%
pos_final_missing_data_test = pos_final_missing_data_test.fillna(-9999)

# %%
model_cols = ~pos_final_test.columns.isin(['(\'subject_id\', \'\')', '(\'hadm_id\', \'\')', 'subject_id', 'hadm_id', 'Unnamed: 0', 'pos'])
# model_cols = pos_final_test.columns.str.contains('mean') | pos_final_test.columns.str.contains('below') | pos_final_test.columns.str.contains('above') | pos_final_test.columns.str.contains('abn') | pos_final_test.columns.isin(['gender', 'age','ethnicity_AMERICAN INDIAN/ALASKA NATIVE', 'ethnicity_ASIAN','ethnicity_BLACK/AFRICAN AMERICAN', 'ethnicity_HISPANIC/LATINO','ethnicity_OTHER', 'ethnicity_UNKNOWN'])

# hadm_features = pos_final_test.loc[:, model_cols]
# hadm_target = pos_final_test.loc[:, 'pos']

hadm_features = pos_final_test_KNN.loc[:, model_cols]
hadm_target = pos_final_test_KNN.loc[:, 'pos']

# hadm_features = pos_final_missing_data_test.loc[:, model_cols]
# hadm_target = pos_final_missing_data_test.loc[:, 'pos']

# %%
X_train, X_test, y_train, y_test = train_test_split(hadm_features, hadm_target, stratify=hadm_target, random_state=0)

# %%
sm = SMOTE()
X_res_over, y_res_over = sm.fit_resample(X_train, y_train)

# %% [markdown]
# ## Principal Component Analysis

# %%
# %%time

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV


# Define a pipeline to search for the best combination of PCA truncation
# and classifier regularization.
pca = PCA()
# set the tolerance to a large value to make the example faster
logistic = LogisticRegression(max_iter=10000, tol=0.1, class_weight = "balanced")
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

X_digits, y_digits = X_train, y_train
# X_digits, y_digits = X_res_over, y_res_over

# Parameters of pipelines can be set using ‘__’ separated parameter names:
param_grid = {
    'pca__n_components': range(5, 125, 15),
    'logistic__C': np.logspace(-6, 1, 4),
}
search = GridSearchCV(pipe, param_grid, n_jobs=-1)
search.fit(X_digits, y_digits)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)

# Plot the PCA spectrum
pca.fit(X_digits)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(np.arange(1, pca.n_components_ + 1),
         pca.explained_variance_ratio_, '+', linewidth=2)
ax0.set_ylabel('PCA explained variance ratio')

ax0.axvline(search.best_estimator_.named_steps['pca'].n_components,
            linestyle=':', label='n_components chosen')
ax0.legend(prop=dict(size=12))

# For each number of components, find the best classifier results
results = pd.DataFrame(search.cv_results_)
components_col = 'param_pca__n_components'
best_clfs = results.groupby(components_col).apply(
    lambda g: g.nlargest(1, 'mean_test_score'))

best_clfs.plot(x=components_col, y='mean_test_score', yerr='std_test_score',
               legend=False, ax=ax1)
ax1.set_ylabel('Classification accuracy (val)')
ax1.set_xlabel('n_components')

plt.xlim(-1, 70)

plt.tight_layout()
plt.show()
# Out:
# Best parameter (CV score=0.826):
# {'logistic__C': 0.00021544346900318845, 'pca__n_components': 80}
# CPU times: user 4.12 s, sys: 300 ms, total: 4.42 s
# Wall time: 6.49 s

# %%
pred = search.predict(X_test)

print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print("Classification Report:", end='')
print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

svc_disp = plot_roc_curve(search, X_test, y_test)
plt.show()
# Out:
# Accuracy Score: 81.81%
# _______________________________________________
# Classification Report:	Precision Score: 41.04%
# 			Recall Score: 74.00%
# 			F1 score: 52.79%
# _______________________________________________
# Confusion Matrix:
#  [[1564  319]
#  [  78  222]]

# %%
# pd.DataFrame(pca.components_[:5],columns=X_train.columns)
pca_coef = pd.DataFrame(list(zip(pca.components_[0], X_train.columns)))
pca_coef.columns = ['coef', 'test']
pca_coef['coef'] = abs(pca_coef['coef'])
pca_coef.sort_values(by = 'coef', ascending = False).head(30)
# Out:
#          coef                                               test
# 15   0.182001         ('min', 'Hemoglobin - Blood - Hematology')
# 115  0.177503   ('below_min', 'Hemoglobin - Blood - Hematology')
# 14   0.176747         ('min', 'Hematocrit - Blood - Hematology')
# 22   0.176055    ('min', 'Red Blood Cells - Blood - Hematology')
# 122  0.175649  ('below_min', 'Red Blood Cells - Blood - Hemat...
# 114  0.175298   ('below_min', 'Hematocrit - Blood - Hematology')
# 65   0.169986        ('mean', 'Hemoglobin - Blood - Hematology')
# 64   0.163933        ('mean', 'Hematocrit - Blood - Hematology')
# 72   0.163057   ('mean', 'Red Blood Cells - Blood - Hematology')
# 38   0.149840       ('max', 'Urea Nitrogen - Blood - Chemistry')
# 138  0.146615  ('above_max', 'Urea Nitrogen - Blood - Chemist...
# 46   0.139430                ('max', 'RDW - Blood - Hematology')
# 2    0.128480      ('min', 'Calcium, Total - Blood - Chemistry')
# 63   0.126143      ('mean', 'Urea Nitrogen - Blood - Chemistry')
# 40   0.124490         ('max', 'Hemoglobin - Blood - Hematology')
# 89   0.124282  ('abn_percent', 'Hematocrit - Blood - Hematolo...
# 101  0.123443   ('below_min', 'Bicarbonate - Blood - Chemistry')
# 90   0.123342  ('abn_percent', 'Hemoglobin - Blood - Hematolo...
# 71   0.121546               ('mean', 'RDW - Blood - Hematology')
# 102  0.121086  ('below_min', 'Calcium, Total - Blood - Chemis...
# 30   0.120767          ('max', 'Creatinine - Blood - Chemistry')
# 1    0.120170         ('min', 'Bicarbonate - Blood - Chemistry')
# 134  0.118182     ('above_max', 'Phosphate - Blood - Chemistry')
# 47   0.118110    ('max', 'Red Blood Cells - Blood - Hematology')
# 34   0.117084           ('max', 'Phosphate - Blood - Chemistry')
# 130  0.116016    ('above_max', 'Creatinine - Blood - Chemistry')
# 39   0.112788         ('max', 'Hematocrit - Blood - Hematology')
# 146  0.112344          ('above_max', 'RDW - Blood - Hematology')
# 97   0.110423  ('abn_percent', 'Red Blood Cells - Blood - Hem...
# 96   0.110135        ('abn_percent', 'RDW - Blood - Hematology')

# %% [markdown]
# ## Recusive Feture Elimination - Recall

# %%
# %%time

import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

logReg = LogisticRegression(penalty = 'l1', max_iter = 2000, class_weight = "balanced", solver = 'liblinear')

rfecv = RFECV(estimator=logReg, step=1, cv=StratifiedKFold(3),
              scoring='recall', n_jobs = -1)

params_log = [ {'estimator__C':np.logspace(-4, 3, 20)} ]

grid_log = GridSearchCV(estimator = rfecv, param_grid = params_log, cv = 3, scoring='recall', verbose = 1)
grid_log.fit(X_train, y_train)
# grid_log.best_score_
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# ...
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# Fitting estimator with 149 features.
# Fitting estimator with 148 features.
# Fitting estimator with 147 features.
# Fitting estimator with 146 features.
# Fitting estimator with 145 features.
# Fitting estimator with 144 features.
# Fitting estimator with 143 features.
# Fitting estimator with 142 features.
# Fitting estimator with 141 features.
# Fitting estimator with 140 features.
# Fitting estimator with 139 features.
# Fitting estimator with 138 features.
# Fitting estimator with 137 features.
# Fitting estimator with 136 features.
# Fitting estimator with 135 features.
# Fitting estimator with 134 features.
# Fitting estimator with 133 features.
# Fitting estimator with 132 features.
# Fitting estimator with 131 features.
# Fitting estimator with 130 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 158 features.
# Fitting estimator with 157 features.
# Fitting estimator with 156 features.
# Fitting estimator with 155 features.
# Fitting estimator with 154 features.
# Fitting estimator with 153 features.
# Fitting estimator with 152 features.
# Fitting estimator with 151 features.
# Fitting estimator with 150 features.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-ae29d03ef334> in <module>
#      12
#      13 grid_log = GridSearchCV(estimator = rfecv, param_grid = params_log, cv = 3, scoring='recall', verbose = 1)
# ---> 14 grid_log.fit(X_train, y_train)
#      15 # grid_log.best_score_
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in fit(self, X, y, groups)
#     550         scores = parallel(
#     551             func(rfe, self.estimator, X, y, train, test, scorer)
# --> 552             for train, test in cv.split(X, y, groups))
#     553
#     554         scores = np.sum(scores, axis=0)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in <genexpr>(.0)
#     550         scores = parallel(
#     551             func(rfe, self.estimator, X, y, train, test, scorer)
# --> 552             for train, test in cv.split(X, y, groups))
#     553
#     554         scores = np.sum(scores, axis=0)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in _rfe_single_fit(rfe, estimator, X, y, train, test, scorer)
#      32     X_test, y_test = _safe_split(estimator, X, y, test, train)
#      33     return rfe._fit(
# ---> 34         X_train, y_train, lambda estimator, features:
#      35         _score(estimator, X_test[:, features], y_test, scorer)).scores_
#      36
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_selection/_rfe.py in _fit(self, X, y, step_score)
#     194                 print("Fitting estimator with %d features." % np.sum(support_))
#     195
# --> 196             estimator.fit(X[:, features], y)
#     197
#     198             # Get coefs
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1358                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1359                 self.max_iter, self.tol, self.random_state,
# -> 1360                 sample_weight=sample_weight)
#    1361             self.n_iter_ = np.array([n_iter_])
#    1362             return self
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     967         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     968         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 969         epsilon, sample_weight)
#     970     # Regarding rnd.randint(..) in the above signature:
#     971     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
print("Optimal number of features : %d" % rfecv.n_features_)

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 76

# %%
rfecv.estimator_.coef_[0]

# X_train.iloc[:, rfecv.support_].columns

# X_train.columns#.iloc[rfecv.support_]
# rfecv.support_
# Out:
# array([-0.32985836,  0.29055606,  0.16228961,  0.32333187, -0.22131817,
#        -0.11866621,  0.12505998, -0.3119563 ,  0.15322705, -0.35055392,
#         0.65629957, -0.20107864,  1.88603497, -3.00126365,  1.48998044,
#        -0.30298069,  0.48249312,  0.284745  ,  0.9069659 , -0.4074037 ,
#         0.37554825, -1.21503924,  0.47179352, -0.88336099, -0.19033332,
#         0.14504164, -0.11281294, -0.4670158 , -0.56286527, -0.75614099,
#         0.20761161, -0.12220821,  0.33595228, -0.21266641,  0.44755379,
#         0.35239254,  0.15399603,  0.20462966,  0.16374082,  0.23965552,
#         0.2345302 , -0.15928196, -0.15757803,  0.18741742,  0.12084301,
#        -0.20763556,  0.15127164,  0.1964918 ,  0.16400682,  0.11987965,
#        -0.15105875, -0.33786255, -0.25623683, -0.40257113, -0.11320045,
#         0.21803477, -0.16552826,  0.29720903, -0.14961014,  0.68483488,
#        -1.45406868,  2.90870142, -1.3972173 , -0.25758647, -0.32337465,
#        -0.97679576, -0.19518223,  1.41342463, -0.60144354,  0.11349999,
#         0.77152977, -0.29571218,  0.78581357, -0.3251329 , -0.14849537,
#        -0.318894  ])

# %%
est_coefs = pd.Series(rfecv.estimator_.coef_[0], index=X_train.iloc[:, rfecv.support_].columns)

sortedCoefs = np.abs(est_coefs).sort_values(ascending=False)
sortedCoefs[sortedCoefs > 0]#.head(50)
# Out:
# ('max', 'Glucose - Blood - Chemistry')                   3.001264
# ('above_max', 'Glucose - Blood - Chemistry')             2.908701
# ('max', 'Creatinine - Blood - Chemistry')                1.886035
# ('max', 'Magnesium - Blood - Chemistry')                 1.489980
# ('above_max', 'Creatinine - Blood - Chemistry')          1.454069
#                                                            ...
# ('abn_percent', 'RDW - Blood - Hematology')              0.119880
# ('min', 'Magnesium - Blood - Chemistry')                 0.118666
# ('above_max', 'Red Blood Cells - Blood - Hematology')    0.113500
# ('below_min', 'MCH - Blood - Hematology')                0.113200
# ('mean', 'Bicarbonate - Blood - Chemistry')              0.112813
# Length: 76, dtype: float64

# %%
X_train_trimmed = X_train.iloc[:, rfecv.support_]
# y_train_trimmed = y_train.iloc[:, rfecv.support_]

X_test_trimmed = X_test.iloc[:, rfecv.support_]
# y_test_trimmed = y_test.iloc[:, rfecv.support_]

# %%
from sklearn.base import clone

best_est = clone(rfecv.estimator_)
best_est.fit(X_train_trimmed, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=2000, penalty='l1',
#                    solver='liblinear')

# %%
est_coefs = pd.Series(best_est.coef_[0], index=X_train.iloc[:, rfecv.support_].columns)

sortedCoefs = np.abs(est_coefs).sort_values(ascending=False)
sortedCoefs[sortedCoefs > 0]#.head(50)
# Out:
# ('max', 'Glucose - Blood - Chemistry')                   2.977939
# ('above_max', 'Glucose - Blood - Chemistry')             2.885731
# ('max', 'Creatinine - Blood - Chemistry')                1.885692
# ('max', 'Magnesium - Blood - Chemistry')                 1.489651
# ('above_max', 'Creatinine - Blood - Chemistry')          1.453679
#                                                            ...
# ('abn_percent', 'RDW - Blood - Hematology')              0.119877
# ('min', 'Magnesium - Blood - Chemistry')                 0.118777
# ('above_max', 'Red Blood Cells - Blood - Hematology')    0.113472
# ('below_min', 'MCH - Blood - Hematology')                0.113189
# ('mean', 'Bicarbonate - Blood - Chemistry')              0.112863
# Length: 76, dtype: float64

# %%
pred = rfecv.estimator_.predict(X_test_trimmed)

print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print("Classification Report:", end='')
print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

svc_disp = plot_roc_curve(search, X_test, y_test)
plt.show()
# Out:
# Accuracy Score: 81.36%
# _______________________________________________
# Classification Report:	Precision Score: 40.66%
# 			Recall Score: 77.67%
# 			F1 score: 53.38%
# _______________________________________________
# Confusion Matrix:
#  [[1543  340]
#  [  67  233]]

# %% [markdown]
# ## Recusive Feture Elimination

# %%
# %%time


import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

# Create the RFE object and compute a cross-validated score.
logReg = LogisticRegression(penalty = 'l1', max_iter = 2000, class_weight = "balanced", solver = 'liblinear')
# The "accuracy" scoring is proportional to the number of correct
# classifications
rfecv = RFECV(estimator=logReg, step=1, cv=StratifiedKFold(3),
              scoring='roc_auc', verbose = 1)
rfecv.fit(X_train, y_train)

# X_train, X_test, y_train, y_test
# Out:
# RFECV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#       estimator=LogisticRegression(class_weight='balanced', max_iter=2000,
#                                    penalty='l1', solver='liblinear'),
#       scoring='roc_auc')

# %%
print("Optimal number of features : %d" % rfecv.n_features_)

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 76

# %%
rfecv.estimator_.coef_[0]

# X_train.iloc[:, rfecv.support_].columns

# X_train.columns#.iloc[rfecv.support_]
# rfecv.support_
# Out:
# array([-0.32985836,  0.29055606,  0.16228961,  0.32333187, -0.22131817,
#        -0.11866621,  0.12505998, -0.3119563 ,  0.15322705, -0.35055392,
#         0.65629957, -0.20107864,  1.88603497, -3.00126365,  1.48998044,
#        -0.30298069,  0.48249312,  0.284745  ,  0.9069659 , -0.4074037 ,
#         0.37554825, -1.21503924,  0.47179352, -0.88336099, -0.19033332,
#         0.14504164, -0.11281294, -0.4670158 , -0.56286527, -0.75614099,
#         0.20761161, -0.12220821,  0.33595228, -0.21266641,  0.44755379,
#         0.35239254,  0.15399603,  0.20462966,  0.16374082,  0.23965552,
#         0.2345302 , -0.15928196, -0.15757803,  0.18741742,  0.12084301,
#        -0.20763556,  0.15127164,  0.1964918 ,  0.16400682,  0.11987965,
#        -0.15105875, -0.33786255, -0.25623683, -0.40257113, -0.11320045,
#         0.21803477, -0.16552826,  0.29720903, -0.14961014,  0.68483488,
#        -1.45406868,  2.90870142, -1.3972173 , -0.25758647, -0.32337465,
#        -0.97679576, -0.19518223,  1.41342463, -0.60144354,  0.11349999,
#         0.77152977, -0.29571218,  0.78581357, -0.3251329 , -0.14849537,
#        -0.318894  ])

# %%
est_coefs = pd.Series(rfecv.estimator_.coef_[0], index=X_train.iloc[:, rfecv.support_].columns)

sortedCoefs = np.abs(est_coefs).sort_values(ascending=False)
sortedCoefs[sortedCoefs > 0]#.head(50)
# Out:
# ('max', 'Glucose - Blood - Chemistry')                   3.001264
# ('above_max', 'Glucose - Blood - Chemistry')             2.908701
# ('max', 'Creatinine - Blood - Chemistry')                1.886035
# ('max', 'Magnesium - Blood - Chemistry')                 1.489980
# ('above_max', 'Creatinine - Blood - Chemistry')          1.454069
#                                                            ...
# ('abn_percent', 'RDW - Blood - Hematology')              0.119880
# ('min', 'Magnesium - Blood - Chemistry')                 0.118666
# ('above_max', 'Red Blood Cells - Blood - Hematology')    0.113500
# ('below_min', 'MCH - Blood - Hematology')                0.113200
# ('mean', 'Bicarbonate - Blood - Chemistry')              0.112813
# Length: 76, dtype: float64

# %%
X_train_trimmed = X_train.iloc[:, rfecv.support_]
# y_train_trimmed = y_train.iloc[:, rfecv.support_]

X_test_trimmed = X_test.iloc[:, rfecv.support_]
# y_test_trimmed = y_test.iloc[:, rfecv.support_]

# %%
from sklearn.base import clone

best_est = clone(rfecv.estimator_)
best_est.fit(X_train_trimmed, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=2000, penalty='l1',
#                    solver='liblinear')

# %%
est_coefs = pd.Series(best_est.coef_[0], index=X_train.iloc[:, rfecv.support_].columns)

sortedCoefs = np.abs(est_coefs).sort_values(ascending=False)
sortedCoefs[sortedCoefs > 0]#.head(50)
# Out:
# ('max', 'Glucose - Blood - Chemistry')                   2.977939
# ('above_max', 'Glucose - Blood - Chemistry')             2.885731
# ('max', 'Creatinine - Blood - Chemistry')                1.885692
# ('max', 'Magnesium - Blood - Chemistry')                 1.489651
# ('above_max', 'Creatinine - Blood - Chemistry')          1.453679
#                                                            ...
# ('abn_percent', 'RDW - Blood - Hematology')              0.119877
# ('min', 'Magnesium - Blood - Chemistry')                 0.118777
# ('above_max', 'Red Blood Cells - Blood - Hematology')    0.113472
# ('below_min', 'MCH - Blood - Hematology')                0.113189
# ('mean', 'Bicarbonate - Blood - Chemistry')              0.112863
# Length: 76, dtype: float64

# %%
pred = rfecv.estimator_.predict(X_test_trimmed)

print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print("Classification Report:", end='')
print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

svc_disp = plot_roc_curve(search, X_test, y_test)
plt.show()
# Out:
# Accuracy Score: 81.36%
# _______________________________________________
# Classification Report:	Precision Score: 40.66%
# 			Recall Score: 77.67%
# 			F1 score: 53.38%
# _______________________________________________
# Confusion Matrix:
#  [[1543  340]
#  [  67  233]]

# %% [markdown]
# ## Limit features before Logistic Regression?

# %%
# Limit to import features as dictated by PCA

model_cols = pos_final_test.columns.isin(['gender', 'age','ethnicity_AMERICAN INDIAN/ALASKA NATIVE', 'ethnicity_ASIAN','ethnicity_BLACK/AFRICAN AMERICAN', 'ethnicity_HISPANIC/LATINO','ethnicity_OTHER', 'ethnicity_UNKNOWN',
                                         '(\'min\', \'Hemoglobin - Blood - Hematology\')',
                                         '(\'below_min\', \'Hemoglobin - Blood - Hematology\')',
                                         '(\'min\', \'Hematocrit - Blood - Hematology\')',
                                         '(\'below_min\', \'Hematocrit - Blood - Hematology\')',
                                         '(\'min\', \'Red Blood Cells - Blood - Hematology\')',
                                         '(\'below_min\', \'Red Blood Cells - Blood - Hematology\')',
                                         '(\'mean\', \'Hemoglobin - Blood - Hematology\')',
                                         '(\'mean\', \'Hematocrit - Blood - Hematology\')',
                                         '(\'mean\', \'Red Blood Cells - Blood - Hematology\')'])
# sum(model_cols)

hadm_features = pos_final_test_KNN.loc[:, model_cols]
hadm_target = pos_final_test_KNN.loc[:, 'pos']

X_train, X_test, y_train, y_test = train_test_split(hadm_features, hadm_target, stratify=hadm_target, random_state=0)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
# %%time

# # L2
# params_log = [ {'C':np.logspace(-4, 3, 20)} ]
# logReg = LogisticRegression(max_iter = 2000, class_weight = "balanced")

# L1
params_log = [ {'C':np.logspace(-4, 3, 20)} ]
logReg = LogisticRegression(penalty = 'l1', max_iter = 2000, class_weight = "balanced", solver = 'liblinear')

grid_log = GridSearchCV(estimator = logReg, param_grid = params_log, cv = 5, scoring='roc_auc')
grid_log.fit(X_train, y_train)
grid_log.best_score_
# Out:
# CPU times: user 46 s, sys: 3.76 s, total: 49.8 s
# Wall time: 18.9 s
# 0.7951037996517305

# %%
grid_log.best_params_
# Out:
# {'C': 0.4832930238571752}

# %%
est_coefs = pd.Series(grid_log.best_estimator_.coef_[0], index=X_train.columns)

sortedCoefs = np.abs(est_coefs).sort_values(ascending=False)
sortedCoefs[sortedCoefs > 0].head(50)
# Out:
# ('mean', 'Hematocrit - Blood - Hematology')              2.104181
# ('mean', 'Hemoglobin - Blood - Hematology')              2.033314
# age                                                      1.085233
# ethnicity_ASIAN                                          0.478700
# ('below_min', 'Red Blood Cells - Blood - Hematology')    0.466787
# ('mean', 'Red Blood Cells - Blood - Hematology')         0.445433
# gender                                                   0.396861
# ethnicity_OTHER                                          0.339333
# ('min', 'Red Blood Cells - Blood - Hematology')          0.296212
# ethnicity_BLACK/AFRICAN AMERICAN                         0.250891
# ('min', 'Hematocrit - Blood - Hematology')               0.249431
# ethnicity_HISPANIC/LATINO                                0.135354
# ('below_min', 'Hemoglobin - Blood - Hematology')         0.119044
# ethnicity_UNKNOWN                                        0.055999
# dtype: float64

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %%
pred = grid_log.predict(X_test)

print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print("Classification Report:", end='')
print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
print("_______________________________________________")
print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")
# Out:
# Accuracy Score: 69.54%
# _______________________________________________
# Classification Report:	Precision Score: 27.66%
# 			Recall Score: 75.33%
# 			F1 score: 40.47%
# _______________________________________________
# Confusion Matrix:
#  [[1292  591]
#  [  74  226]]

# %% [markdown]
# ## Random Forest

# %%
from sklearn import ensemble
import sklearn.model_selection as ms

randomForest = ensemble.RandomForestClassifier(class_weight = "balanced")

# %%
# %%time

grid_para_forest = {
    'criterion': ['gini', 'entropy'],
    'max_depth': range(1, 20),
    'n_estimators': range(10, 110, 10)
}

grid_search_forest = ms.GridSearchCV(randomForest, grid_para_forest, scoring='accuracy', cv=5, n_jobs=-1)
grid_search_forest.fit(X_train, y_train)
# Out:
# CPU times: user 11.2 s, sys: 806 ms, total: 12 s
# Wall time: 3min 30s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(class_weight='balanced'),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 20),
#                          'n_estimators': range(10, 110, 10)},
#              scoring='accuracy')

# %%
# Get most important features
tree_final = grid_search_forest.best_estimator_
feature_importance = tree_final.feature_importances_
feature_importance = list(zip(X_train.columns, feature_importance))

feature_importance.sort(key = lambda x: x[1], reverse = True)
feature_importance
# Out:
# [("('above_max', 'Urea Nitrogen - Blood - Chemistry')", 0.04476545466647504),
#  ("('max', 'Urea Nitrogen - Blood - Chemistry')", 0.03933831141007367),
#  ("('mean', 'Urea Nitrogen - Blood - Chemistry')", 0.03625201370023889),
#  ('age', 0.03254624294602057),
#  ("('max', 'Creatinine - Blood - Chemistry')", 0.022338388661912928),
#  ("('mean', 'Creatinine - Blood - Chemistry')", 0.021632043257390956),
#  ("('min', 'MCHC - Blood - Hematology')", 0.017623788522637053),
#  ("('min', 'Urea Nitrogen - Blood - Chemistry')", 0.017494006281645692),
#  ("('mean', 'Troponin T - Blood - Chemistry')", 0.017422192222499702),
#  ("('max', 'Troponin T - Blood - Chemistry')", 0.017136653434649627),
#  ("('abn_percent', 'Creatinine - Blood - Chemistry')", 0.016136799275294128),
#  ("('max', 'RDW - Blood - Hematology')", 0.015882423718363937),
#  ("('mean', 'RDW - Blood - Hematology')", 0.01586425619610085),
#  ("('above_max', 'PT - Blood - Hematology')", 0.0155797245661866),
#  ("('mean', 'PT - Blood - Hematology')", 0.013952139607546052),
#  ("('mean', 'MCHC - Blood - Hematology')", 0.013938023407835934),
#  ("('min', 'Troponin T - Blood - Chemistry')", 0.013897882575845334),
#  ("('max', 'PT - Blood - Hematology')", 0.01313565876542216),
#  ("('min', 'RDW - Blood - Hematology')", 0.012312194935722236),
#  ("('min', 'PT - Blood - Hematology')", 0.011780351693053597),
#  ("('abn_percent', 'Urea Nitrogen - Blood - Chemistry')",
#   0.011732042707428822),
#  ("('max', 'Glucose - Blood - Chemistry')", 0.011656536506117596),
#  ("('above_max', 'Troponin T - Blood - Chemistry')", 0.011333877940862883),
#  ("('max', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')",
#   0.011189405555870084),
#  ("('abn_percent', 'Troponin T - Blood - Chemistry')", 0.010747285914251477),
#  ("('abn_percent', 'PT - Blood - Hematology')", 0.010571505384749314),
#  ("('max', 'MCHC - Blood - Hematology')", 0.01023458262524035),
#  ("('above_max', 'Glucose - Blood - Chemistry')", 0.00999075099302729),
#  ("('mean', 'Chloride - Blood - Chemistry')", 0.009456845631494864),
#  ("('max', 'Bicarbonate - Blood - Chemistry')", 0.009368963731239466),
#  ("('mean', 'Bicarbonate - Blood - Chemistry')", 0.008883295262006211),
#  ("('mean', 'Phosphate - Blood - Chemistry')", 0.00866183794751527),
#  ("('min', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')",
#   0.008557993918114307),
#  ("('mean', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')",
#   0.008522964198828161),
#  ("('min', 'Platelet Count - Blood - Hematology')", 0.00838662352951383),
#  ("('mean', 'White Blood Cells - Blood - Hematology')", 0.008308641516305046),
#  ("('mean', 'Anion Gap - Blood - Chemistry')", 0.00828425073556283),
#  ("('mean', 'MCV - Blood - Hematology')", 0.008197134453964982),
#  ("('max', 'Calcium, Total - Blood - Chemistry')", 0.008083228741586906),
#  ("('mean', 'Glucose - Blood - Chemistry')", 0.008027844414713051),
#  ("('min', 'White Blood Cells - Blood - Hematology')", 0.008011633509875944),
#  ("('mean', 'Calcium, Total - Blood - Chemistry')", 0.00785751085028239),
#  ("('max', 'White Blood Cells - Blood - Hematology')", 0.007819079550889068),
#  ("('max', 'Phosphate - Blood - Chemistry')", 0.007812232968181042),
#  ("('min', 'Glucose - Blood - Chemistry')", 0.007698731856280274),
#  ("('mean', 'Sodium - Blood - Chemistry')", 0.007524340779073976),
#  ("('max', 'Potassium - Blood - Chemistry')", 0.007501177432143169),
#  ("('min', 'Calcium, Total - Blood - Chemistry')", 0.007432833523140278),
#  ("('mean', 'Estimated GFR (MDRD equation) - Blood - Chemistry')",
#   0.007429804196570314),
#  ("('max', 'Platelet Count - Blood - Hematology')", 0.007413021346398768),
#  ("('mean', 'Platelet Count - Blood - Hematology')", 0.007392223066522749),
#  ("('mean', 'Magnesium - Blood - Chemistry')", 0.007282763354256323),
#  ("('mean', 'Potassium - Blood - Chemistry')", 0.007266405576188774),
#  ("('max', 'MCV - Blood - Hematology')", 0.007204927425933419),
#  ("('above_max', 'Creatinine - Blood - Chemistry')", 0.007031670907316603),
#  ("('max', 'Estimated GFR (MDRD equation) - Blood - Chemistry')",
#   0.007012397747286893),
#  ("('min', 'MCH - Blood - Hematology')", 0.006904437707879249),
#  ("('mean', 'MCH - Blood - Hematology')", 0.006685483271536637),
#  ("('min', 'Red Blood Cells - Blood - Hematology')", 0.006640472473448395),
#  ("('min', 'Creatinine - Blood - Chemistry')", 0.006616137215139104),
#  ("('max', 'Chloride - Blood - Chemistry')", 0.006600968177851288),
#  ("('min', 'Hematocrit - Blood - Hematology')", 0.006575544153045347),
#  ("('min', 'Estimated GFR (MDRD equation) - Blood - Chemistry')",
#   0.006559188347542018),
#  ("('max', 'Hematocrit - Blood - Hematology')", 0.006334092938108764),
#  ("('max', 'Magnesium - Blood - Chemistry')", 0.00628575591015209),
#  ("('below_min', 'Hematocrit - Blood - Hematology')", 0.006242976170754332),
#  ("('min', 'Phosphate - Blood - Chemistry')", 0.00617625525517149),
#  ("('mean', 'Red Blood Cells - Blood - Hematology')", 0.006100755654932446),
#  ("('below_min', 'Red Blood Cells - Blood - Hematology')",
#   0.006088872153708547),
#  ("('max', 'MCH - Blood - Hematology')", 0.006058926017160454),
#  ("('min', 'Chloride - Blood - Chemistry')", 0.006035045731104639),
#  ("('min', 'Sodium - Blood - Chemistry')", 0.005996538316803781),
#  ("('mean', 'Hematocrit - Blood - Hematology')", 0.0059658425623641854),
#  ("('abn_percent', 'Glucose - Blood - Chemistry')", 0.005916166222293256),
#  ("('min', 'Bicarbonate - Blood - Chemistry')", 0.005876808397536603),
#  ("('max', 'Red Blood Cells - Blood - Hematology')", 0.005859543439025687),
#  ("('below_min', 'Hemoglobin - Blood - Hematology')", 0.005768707116882457),
#  ("('max', 'Hemoglobin - Blood - Hematology')", 0.005600821746656752),
#  ("('mean', 'Hemoglobin - Blood - Hematology')", 0.005564740388039715),
#  ("('min', 'Hemoglobin - Blood - Hematology')", 0.005474089048842761),
#  ("('min', 'MCV - Blood - Hematology')", 0.0054634024733546185),
#  ("('max', 'Anion Gap - Blood - Chemistry')", 0.005269577378666826),
#  ("('min', 'Anion Gap - Blood - Chemistry')", 0.005128443446821765),
#  ("('min', 'Potassium - Blood - Chemistry')", 0.005003779605609984),
#  ("('max', 'Sodium - Blood - Chemistry')", 0.004701309843598731),
#  ("('below_min', 'MCHC - Blood - Hematology')", 0.0043674641607662785),
#  ("('min', 'Magnesium - Blood - Chemistry')", 0.004302634305156569),
#  ("('abn_percent', 'Phosphate - Blood - Chemistry')", 0.00405124700820272),
#  ("('abn_percent', 'Calcium, Total - Blood - Chemistry')",
#   0.003942519066727598),
#  ("('abn_percent', 'Bicarbonate - Blood - Chemistry')", 0.0036959027230524305),
#  ("('above_max', 'White Blood Cells - Blood - Hematology')",
#   0.0035642502919987482),
#  ("('abn_percent', 'White Blood Cells - Blood - Hematology')",
#   0.003510030337513658),
#  ("('above_max', 'RDW - Blood - Hematology')", 0.003486245411643838),
#  ("('below_min', 'Calcium, Total - Blood - Chemistry')",
#   0.0033681522775305915),
#  ("('below_min', 'Platelet Count - Blood - Hematology')",
#   0.0031332406957598315),
#  ("('abn_percent', 'RDW - Blood - Hematology')", 0.0031266940526562996),
#  ("('above_max', 'Chloride - Blood - Chemistry')", 0.002996312533335583),
#  ("('above_max', 'Bicarbonate - Blood - Chemistry')", 0.002908530452140547),
#  ("('abn_percent', 'MCHC - Blood - Hematology')", 0.0028788689774786155),
#  ("('below_min', 'Phosphate - Blood - Chemistry')", 0.0028641517063732777),
#  ("('abn_percent', 'Magnesium - Blood - Chemistry')", 0.0026610391387884656),
#  ("('above_max', 'MCHC - Blood - Hematology')", 0.002492745627094288),
#  ("('below_min', 'Estimated GFR (MDRD equation) - Blood - Chemistry')",
#   0.002422911080722954),
#  ("('abn_percent', 'Platelet Count - Blood - Hematology')",
#   0.002321863543933963),
#  ("('abn_percent', 'Sodium - Blood - Chemistry')", 0.0022269762803117706),
#  ("('below_min', 'Bicarbonate - Blood - Chemistry')", 0.0021555453521150416),
#  ("('abn_percent', 'Hemoglobin - Blood - Hematology')", 0.002151377020774457),
#  ("('above_max', 'MCH - Blood - Hematology')", 0.0020840783886908443),
#  ("('abn_percent', 'Potassium - Blood - Chemistry')", 0.0020781812949938927),
#  ("('abn_percent', 'Chloride - Blood - Chemistry')", 0.0020288297907305386),
#  ("('abn_percent', 'Hematocrit - Blood - Hematology')", 0.002009501490238038),
#  ("('above_max', 'Phosphate - Blood - Chemistry')", 0.00191868852865087),
#  ("('above_max', 'Potassium - Blood - Chemistry')", 0.0017231444953538695),
#  ("('abn_percent', 'MCH - Blood - Hematology')", 0.0017201044755939209),
#  ("('below_min', 'Sodium - Blood - Chemistry')", 0.0017011212129750043),
#  ("('below_min', 'Chloride - Blood - Chemistry')", 0.0015666685654824968),
#  ("('abn_percent', 'Anion Gap - Blood - Chemistry')", 0.0015202611708606069),
#  ("('abn_percent', 'MCV - Blood - Hematology')", 0.0014020039402556656),
#  ("('above_max', 'MCV - Blood - Hematology')", 0.001192015743779333),
#  ("('above_max', 'Platelet Count - Blood - Hematology')",
#   0.0011678535390724398),
#  ("('below_min', 'Potassium - Blood - Chemistry')", 0.0010604511455193214),
#  ("('abn_percent', 'Red Blood Cells - Blood - Hematology')",
#   0.0010369468473858585),
#  ('ethnicity_UNKNOWN', 0.0009800362282273779),
#  ("('below_min', 'Anion Gap - Blood - Chemistry')", 0.0009342344701965984),
#  ("('above_max', 'Anion Gap - Blood - Chemistry')", 0.0008617048447756966),
#  ("('below_min', 'Glucose - Blood - Chemistry')", 0.0008610803334319417),
#  ("('below_min', 'Urea Nitrogen - Blood - Chemistry')", 0.0008491460327733786),
#  ("('above_max', 'Sodium - Blood - Chemistry')", 0.0008354533262313659),
#  ("('above_max', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')",
#   0.0008216272991748814),
#  ("('below_min', 'White Blood Cells - Blood - Hematology')",
#   0.000810778542606128),
#  ("('below_min', 'Magnesium - Blood - Chemistry')", 0.000797985024341475),
#  ("('below_min', 'MCH - Blood - Hematology')", 0.0007768464109368051),
#  ("('above_max', 'Magnesium - Blood - Chemistry')", 0.0007522278611623894),
#  ('gender', 0.0006934540567580524),
#  ("('mean', 'Bilirubin - Urine - Hematology')", 0.0006113895995993834),
#  ("('below_min', 'MCV - Blood - Hematology')", 0.000608437935553814),
#  ("('abn_percent', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')",
#   0.0004868116639766259),
#  ('ethnicity_BLACK/AFRICAN AMERICAN', 0.00038919127291754506),
#  ("('max', 'Bilirubin - Urine - Hematology')", 0.00038618119880793526),
#  ('ethnicity_OTHER', 0.0003487486755973169),
#  ("('min', 'Bilirubin - Urine - Hematology')", 0.00031688688046516866),
#  ("('above_max', 'Calcium, Total - Blood - Chemistry')",
#   0.0003012281711703195),
#  ('ethnicity_ASIAN', 0.00026355812449033167),
#  ("('above_max', 'Bilirubin - Urine - Hematology')", 0.00026190380420093427),
#  ("('above_max', 'Hematocrit - Blood - Hematology')", 0.00025364456042053986),
#  ('ethnicity_HISPANIC/LATINO', 0.00023099631823859582),
#  ("('below_min', 'Creatinine - Blood - Chemistry')", 0.00011111945580275034),
#  ("('above_max', 'Red Blood Cells - Blood - Hematology')",
#   0.00010485186542255254),
#  ("('abn_percent', 'Bilirubin - Urine - Hematology')", 8.896781658304134e-05),
#  ('ethnicity_AMERICAN INDIAN/ALASKA NATIVE', 7.478982712797224e-06),
#  ("('below_min', 'PT - Blood - Hematology')", 5.879762084459263e-06),
#  ("('abn_percent', 'Estimated GFR (MDRD equation) - Blood - Chemistry')", 0.0),
#  ("('below_min', 'Creatine Kinase, MB Isoenzyme - Blood - Chemistry')", 0.0),
#  ("('below_min', 'Troponin T - Blood - Chemistry')", 0.0),
#  ("('below_min', 'RDW - Blood - Hematology')", 0.0),
#  ("('below_min', 'Bilirubin - Urine - Hematology')", 0.0),
#  ("('above_max', 'Estimated GFR (MDRD equation) - Blood - Chemistry')", 0.0),
#  ("('above_max', 'Hemoglobin - Blood - Hematology')", 0.0)]

# %%
grid_search_forest.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 16, 'n_estimators': 80}

# %%
grid_search_forest.best_score_
# Out:
# 0.8888375836108212

# %%
print("The training error is: %.5f" % (grid_search_forest.score(X_train, y_train)))
print("The test     error is: %.5f" % (grid_search_forest.score(X_test, y_test)))
# Out:
# The training error is: 0.99969
# The test     error is: 0.88090

# %%
rf_predictions = tree_final.predict(X_test)

print(f"Accuracy Score: {accuracy_score(y_test, rf_predictions) * 100:.2f}%")
print("_______________________________________________")
print("Classification Report:", end='')
print(f"\tPrecision Score: {precision_score(y_test, rf_predictions) * 100:.2f}%")
print(f"\t\t\tRecall Score: {recall_score(y_test, rf_predictions) * 100:.2f}%")
print(f"\t\t\tF1 score: {f1_score(y_test, rf_predictions) * 100:.2f}%")
print("_______________________________________________")
print(f"Confusion Matrix: \n {confusion_matrix(y_test, rf_predictions)}\n")
# Out:
# Accuracy Score: 88.09%
# _______________________________________________
# Classification Report:	Precision Score: 65.15%
# 			Recall Score: 28.67%
# 			F1 score: 39.81%
# _______________________________________________
# Confusion Matrix:
#  [[1837   46]
#  [ 214   86]]
